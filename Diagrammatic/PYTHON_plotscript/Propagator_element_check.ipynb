# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sp
import pandas as pd

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib import cm
from matplotlib.gridspec import GridSpec

# %%
tau = np.linspace(0,2,201)

# %%
def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

c1='red' #blue
c2='yellow' #green

# %%
lab = [i for i in range(1,10,1)]

# %%
for i in range(20):
    globals()['ITE{}'.format(i)]=pd.read_csv('NCA_PROP_CONVERGE_WITH_PARA_GAMMA004_ITE{}.txt'.format(i),header=None,names=['x','a','b','c','d','e','f','g','h','i','j'],delim_whitespace=True)

# %%
ITE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 ITE
#
# NameError: name 'ITE' is not defined

# %%
fig = plt.figure(figsize=(30,20))
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 11})
gs = GridSpec(nrows=3, ncols=3, width_ratios=[1, 1, 1], height_ratios=[1, 1, 1])
#gs = GridSpec(nrows=3, ncols=4, width_ratios=[7, 3, 3], height_ratios=[1, 1, 1])
cmaps = plt.colormaps()
blues = cm.get_cmap("Blues",lut=10)
c_blues = [blues(i) for i in range(20)]
mpl.rcParams['axes.linewidth'] = 1.3

r = cm.get_cmap("Reds",lut=10)
c_reds = [r(i) for i in range(10)]

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[1, 2])
ax6 = fig.add_subplot(gs[2, 0])
ax7 = fig.add_subplot(gs[2, 1])
ax8 = fig.add_subplot(gs[2, 2])

for i in range(20):
    ax0.plot(tau,globals()['ITE{}'.format(i)].a,color=c_blues[i],linewidth='1')
    ax1.plot(tau,globals()['ITE{}'.format(i)].b,color=c_blues[i],linewidth='1')
    ax2.plot(tau,globals()['ITE{}'.format(i)].c,color=c_blues[i],linewidth='1')
    ax3.plot(tau,globals()['ITE{}'.format(i)].d,color=c_blues[i],linewidth='1')
    ax4.plot(tau,globals()['ITE{}'.format(i)].e,color=c_blues[i],linewidth='1')
    ax5.plot(tau,globals()['ITE{}'.format(i)].f,color=c_blues[i],linewidth='1')
    ax6.plot(tau,globals()['ITE{}'.format(i)].g,color=c_blues[i],linewidth='1')
    ax7.plot(tau,globals()['ITE{}'.format(i)].h,color=c_blues[i],linewidth='1')
    ax8.plot(tau,globals()['ITE{}'.format(i)].i,color=c_blues[i],linewidth='1')

    if i == 19:
        ax0.plot(tau,globals()['ITE{}'.format(i)].a,label='1th element',color=c_reds[8],linewidth='2')
        ax1.plot(tau,globals()['ITE{}'.format(i)].b,label='2nd element',color=c_reds[8],linewidth='2')
        ax2.plot(tau,globals()['ITE{}'.format(i)].c,label='3rd element',color=c_reds[8],linewidth='2')
        ax3.plot(tau,globals()['ITE{}'.format(i)].d,label='4th element',color=c_reds[8],linewidth='2')
        ax4.plot(tau,globals()['ITE{}'.format(i)].e,label='5th element',color=c_reds[8],linewidth='2')
        ax5.plot(tau,globals()['ITE{}'.format(i)].f,label='6th element',color=c_reds[8],linewidth='2')
        ax6.plot(tau,globals()['ITE{}'.format(i)].g,label='7th element',color=c_reds[8],linewidth='2')
        ax7.plot(tau,globals()['ITE{}'.format(i)].h,label='8th element',color=c_reds[8],linewidth='2')
        ax8.plot(tau,globals()['ITE{}'.format(i)].i,label='9th element',color=c_reds[8],linewidth='2')



ax0.legend()
ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()
ax5.legend()
ax6.legend()
ax7.legend()
ax8.legend()

#plt.title(r"$\tau$=200")
plt.show()
# Out:
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_19967/1785576492.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   blues = cm.get_cmap("Blues",lut=10)
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_19967/1785576492.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   r = cm.get_cmap("Reds",lut=10)

# %%
fig = plt.figure(figsize=(12,4))
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 11})
gs = GridSpec(nrows=1, ncols=2, width_ratios=[2,1], height_ratios=[1])
#gs = GridSpec(nrows=3, ncols=4, width_ratios=[7, 3, 3], height_ratios=[1, 1, 1])
cmaps = plt.colormaps()
blues = cm.get_cmap("Blues",lut=10)
c_blues = [blues(i) for i in range(10)]
mpl.rcParams['axes.linewidth'] = 1.3

reds = cm.get_cmap("Reds",lut=10)
c_reds = [reds(i) for i in range(10)]

ax0 = fig.add_subplot(gs[0, 0])



ax0.plot(tau,Prof.a,label='Ref_V_func',color=c_blues[5],linewidth='1',marker='.')
ax0.plot(tau,Me.a,label='Test_V_func',color=c_reds[5],linewidth='1',marker='.')
plt.legend()

ax1 = fig.add_subplot(gs[0,1])

ax1.plot(tau,Prof.a-Me.a,label='diff_V_function')
ax1.legend()
# Out:
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/2089676376.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   blues = cm.get_cmap("Blues",lut=10)
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/2089676376.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   reds = cm.get_cmap("Reds",lut=10)
