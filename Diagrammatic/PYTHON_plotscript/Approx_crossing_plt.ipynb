# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.stats import rankdata
from mpl_toolkits.mplot3d import axes3d
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import cm
from matplotlib.gridspec import GridSpec

# %%
gs = GridSpec(nrows=1, ncols=2, width_ratios=[1,1], height_ratios=[1])
cmaps = plt.colormaps()
blues = cm.get_cmap("gnuplot",lut=15)
spec = cm.get_cmap("Purples",lut =12)
c_blues = [blues(i) for i in range(15)]
c_spec = [spec(i) for i in range(13)]

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 11})
# Out:
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_535/1581957719.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   blues = cm.get_cmap("gnuplot",lut=15)
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_535/1581957719.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   spec = cm.get_cmap("Purples",lut =12)

# %% [markdown]
# plot per coupling

# %%
coup = np.linspace(2,20,10)
coupl = [10,12]

#for i in coup:
    #coupl.append(int(i))
beta = [3.3,3.57,3.84,4.16,4.54,5,5.55,6.25,7.14,8.33,10,12.5,16.66,25]
#beta2 = [10,11.4,13.2,15.7,19.5,25.4,36.8,66.7]
a = 0
b=0
c = 0
d = 0

for i in coupl:
    globals()['NCcoup3{}'.format(a)] = pd.read_csv('./OCA_size3_coup_{}.txt'.format(i),header=None,delim_whitespace=True)
    a += 1

for i in coupl:
    globals()['NCcoup5{}'.format(b)] = pd.read_csv('./OCA_size5_coup_{}.txt'.format(i),header=None,delim_whitespace=True)
    b += 1

for i in coupl:
    globals()['NCcoup7{}'.format(c)] = pd.read_csv('./OCA_size7_coup_{}.txt'.format(i),header=None,delim_whitespace=True)
    c += 1

#for i in coupl:
    #globals()['NCcoup9{}'.format(d)] = pd.read_csv('./OCA_size9_coup_{}.txt'.format(i),header=None,delim_whitespace=True)
    #d += 1

# %%
a = 0
b=0
c=0
d=0
mark = ['v','o','D','^','s','p','8','*','D','>','d','<','v','.']

fig = plt.figure(figsize=(8,7))
#plt.title(r"$\alpha$ = " + str(aarr[10]))

err = np.abs(1/beta[1]-1/beta[0])
err2 = np.abs(1/63.83-1/62.5)
err3 = np.abs(1/66.6 - 1/36.8)

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 10})
mpl.rcParams['axes.linewidth'] = 1.5

plt.title("OCA data saturation test : size 3, 5, 7, 9 ")
'''
for i in coupl:
    plt.errorbar(globals()['NCcoup{}'.format(a)][1][-1:],globals()['NCcoup{}'.format(a)][0][-1:],yerr=[[0], [err]],fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.errorbar(globals()['NCcoup{}'.format(a)][1][:-1],globals()['NCcoup{}'.format(a)][0][:-1],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.scatter(globals()['NCcoup{}'.format(a)][1],globals()['NCcoup{}'.format(a)][0],label=r'$\alpha$ = ' + str(i),color = c_spec[a],linewidth =1, marker = mark[a], facecolors = 'none' , s = 100)
    plt.plot(globals()['NCcoup{}'.format(a)][1],globals()['NCcoup{}'.format(a)][0],linewidth=1,ls='--',color = c_spec[a])

    a += 1
#plt.errorbar(NCcoup0[1],NCcoup0[0],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5,label=r' $\pm\frac{\Delta (Temp)}{2}$')
'''
for i in coupl:
    plt.errorbar(globals()['NCcoup3{}'.format(a)][1][-1:],globals()['NCcoup3{}'.format(a)][0][-1:],yerr=[[0], [err]],fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.errorbar(globals()['NCcoup3{}'.format(a)][1][:-1],globals()['NCcoup3{}'.format(a)][0][:-1],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.scatter(globals()['NCcoup3{}'.format(a)][1],globals()['NCcoup3{}'.format(a)][0],label=r'size 3 , $\alpha$ = ' + str(i),color = c_spec[a+7],linewidth =1, marker = mark[a], facecolors = 'none' , s = 100)
    plt.plot(globals()['NCcoup3{}'.format(a)][1],globals()['NCcoup3{}'.format(a)][0],linewidth=1,ls='--',color = c_spec[a+7])

    a += 1
for i in coupl:
    plt.errorbar(globals()['NCcoup5{}'.format(b)][1][-1:],globals()['NCcoup5{}'.format(b)][0][-1:],yerr=[[0], [err]],fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.errorbar(globals()['NCcoup5{}'.format(b)][1][:-1],globals()['NCcoup5{}'.format(b)][0][:-1],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.scatter(globals()['NCcoup5{}'.format(b)][1],globals()['NCcoup5{}'.format(b)][0],label=r'size 5 , $\alpha$ = ' + str(i),color = c_spec[b+10],linewidth =1, marker = mark[b+2], facecolors = 'none' , s = 100)
    plt.plot(globals()['NCcoup5{}'.format(b)][1],globals()['NCcoup5{}'.format(b)][0],linewidth=1,ls='--',color = c_spec[b])

    b += 1
for i in coupl:
    plt.errorbar(globals()['NCcoup7{}'.format(c)][1][-1:],globals()['NCcoup7{}'.format(c)][0][-1:],yerr=[[0], [err]],fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.errorbar(globals()['NCcoup7{}'.format(c)][1][:-1],globals()['NCcoup7{}'.format(c)][0][:-1],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.scatter(globals()['NCcoup7{}'.format(c)][1],globals()['NCcoup7{}'.format(c)][0],label=r'size 7 , $\alpha$ = ' + str(i),color = c_blues[c+6],linewidth =1, marker = 'X', facecolors = 'none' , s = 100)
    plt.plot(globals()['NCcoup7{}'.format(c)][1],globals()['NCcoup7{}'.format(c)][0],linewidth=1,ls='--',color = c_blues[c+6])

    c += 1
for i in coupl:
    plt.errorbar(globals()['NCcoup9{}'.format(d)][1][-1:],globals()['NCcoup9{}'.format(d)][0][-1:],yerr=[[0], [err]],fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.errorbar(globals()['NCcoup9{}'.format(d)][1][:-1],globals()['NCcoup9{}'.format(d)][0][:-1],yerr=err,fmt='', capsize=4, capthick=0.5, ecolor=c_blues[1], linestyle='None',linewidth=0.5)
    plt.scatter(globals()['NCcoup9{}'.format(d)][1],globals()['NCcoup9{}'.format(d)][0],label=r'size 9 , $\alpha$ = ' + str(i),color = c_blues[d+10],linewidth =1, marker = 'P', facecolors = 'none' , s = 100)
    plt.plot(globals()['NCcoup9{}'.format(d)][1],globals()['NCcoup9{}'.format(d)][0],linewidth=1,ls='--',color = c_blues[d+10])

    d += 1

plt.xlabel(r"$\gamma$")
plt.ylabel(r"Temp [1/$\beta$]")
#plt.xlim([0,1])
#plt.ylim([0.0,0.35])

plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')

plt.grid()
plt.legend()
plt.show()

# %%
print(err2)
# Out:
# 0.0003333855553814824
