# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sp
import pandas as pd

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.collections import LineCollection
from matplotlib import cm
from matplotlib.gridspec import GridSpec

# %%
tau = np.linspace(0,2,201)

# %%
def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

c1='red' #blue
c2='yellow' #green

# %%
lab = [i for i in range(1,10,1)]

# %%
Prof = pd.read_csv('St.dat1',header=None,names=['x','a','b','c','d','e','f','g','h','i','j'],delim_whitespace=True)
Me = pd.read_csv('REVTEST_200_ite1.txt',header=None,names=['x','a','b','c','d','e','f','g','h','i'],delim_whitespace=True)

# %%
fig = plt.figure(figsize=(20,8))
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 11})
gs = GridSpec(nrows=3, ncols=4, width_ratios=[6, 1, 1, 1], height_ratios=[1, 1, 1])
#gs = GridSpec(nrows=3, ncols=4, width_ratios=[7, 3, 3], height_ratios=[1, 1, 1])
cmaps = plt.colormaps()
blues = cm.get_cmap("Blues",lut=10)
c_blues = [blues(i) for i in range(10)]
mpl.rcParams['axes.linewidth'] = 1.3

reds = cm.get_cmap("Reds",lut=10)
c_reds = [reds(i) for i in range(10)]

ax0 = fig.add_subplot(gs[:, 0])

ax0.plot(tau,Prof.a,label='Gt.dat_00',color=c_blues[1],linewidth='1',marker='.')
ax0.plot(tau,Prof.b,label='Gt.dat_01',color=c_blues[2],linewidth='1',marker='1')
ax0.plot(tau,Prof.c,label='Gt.dat_02',color=c_blues[3],linewidth='1',marker='2')
ax0.plot(tau,Prof.d,label='Gt.dat_10',color=c_blues[4],linewidth='1',marker='3')
ax0.plot(tau,Prof.e,label='Gt.dat_11',color=c_blues[5],linewidth='1',marker='+')
ax0.plot(tau,Prof.f,label='Gt.dat_12',color=c_blues[6],linewidth='1',marker='x')
ax0.plot(tau,Prof.g,label='Gt.dat_20',color=c_blues[7],linewidth='1',marker='*')
ax0.plot(tau,Prof.h,label='Gt.dat_21',color=c_blues[8],linewidth='1',marker='|')
ax0.plot(tau,Prof.i,label='Gt.dat_22',color=c_blues[9],linewidth='1',marker='_')

ax0.plot(tau,Me.a,label='OCA_sig_00',color=c_reds[1],linewidth='1',marker='.')
ax0.plot(tau,Me.b,label='OCA_sig_01',color=c_reds[2],linewidth='1',marker='1')
ax0.plot(tau,Me.c,label='OCA_sig_02',color=c_reds[3],linewidth='1',marker='2')
ax0.plot(tau,Me.d,label='OCA_sig_10',color=c_reds[4],linewidth='1',marker='3')
ax0.plot(tau,Me.e,label='OCA_sig_11',color=c_reds[5],linewidth='1',marker='+')
ax0.plot(tau,Me.f,label='OCA_sig_12',color=c_reds[6],linewidth='1',marker='x')
ax0.plot(tau,Me.g,label='OCA_sig_20',color=c_reds[7],linewidth='1',marker='*')
ax0.plot(tau,Me.h,label='OCA_sig_21',color=c_reds[8],linewidth='1',marker='|')
ax0.plot(tau,Me.i,label='OCA_sig_22',color=c_reds[9],linewidth='1',marker='_')

#plt.text(1.11,0.76,"3rd_Iteration with reference data",fontsize=13)
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
#plt.ylabel(r"$G_{pp}(\tau)$")
plt.legend(ncol=2)

ax1 = fig.add_subplot(gs[0, 1])
ax1.plot(tau,Prof.a-Me.a,label='diff_prop_00')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax2 = fig.add_subplot(gs[0, 2])
ax2.plot(tau,Prof.b-Me.b,label='diff_prop_01')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax3 = fig.add_subplot(gs[0, 3])
ax3.plot(tau,Prof.c-Me.c,label='diff_prop_02')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(tau,Prof.d-Me.d,label='diff_prop_10')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax5 = fig.add_subplot(gs[1, 2])
ax5.plot(tau,Prof.e-Me.e,label='diff_prop_11')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax6 = fig.add_subplot(gs[1, 3])
ax6.plot(tau,Prof.f-Me.f,label='diff_prop_12')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax7 = fig.add_subplot(gs[2, 1])
ax7.plot(tau,Prof.g-Me.g,label='diff_prop_20')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax8 = fig.add_subplot(gs[2, 2])
ax8.plot(tau,Prof.h-Me.h,label='diff_prop_21')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)

ax9 = fig.add_subplot(gs[2, 3])
ax9.plot(tau,Prof.i-Me.i,label='diff_prop_22')
plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')
plt.grid(color='whitesmoke')
plt.xlabel(r"$\tau$")
plt.legend(loc=4)


plt.show()
# Out:
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/488989682.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   blues = cm.get_cmap("Blues",lut=10)
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/488989682.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   reds = cm.get_cmap("Reds",lut=10)

# %%
fig = plt.figure(figsize=(12,4))
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 11})
gs = GridSpec(nrows=1, ncols=2, width_ratios=[2,1], height_ratios=[1])
#gs = GridSpec(nrows=3, ncols=4, width_ratios=[7, 3, 3], height_ratios=[1, 1, 1])
cmaps = plt.colormaps()
blues = cm.get_cmap("Blues",lut=10)
c_blues = [blues(i) for i in range(10)]
mpl.rcParams['axes.linewidth'] = 1.3

reds = cm.get_cmap("Reds",lut=10)
c_reds = [reds(i) for i in range(10)]

ax0 = fig.add_subplot(gs[0, 0])



ax0.plot(tau,Prof.a,label='Ref_V_func',color=c_blues[5],linewidth='1',marker='.')
ax0.plot(tau,Me.a,label='Test_V_func',color=c_reds[5],linewidth='1',marker='.')
plt.legend()

ax1 = fig.add_subplot(gs[0,1])

ax1.plot(tau,Prof.a-Me.a,label='diff_V_function')
ax1.legend()
# Out:
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/2089676376.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   blues = cm.get_cmap("Blues",lut=10)
# /var/folders/37/nghp0rpn0wqc9tj09h1nlpm00000gn/T/ipykernel_22072/2089676376.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   reds = cm.get_cmap("Reds",lut=10)
